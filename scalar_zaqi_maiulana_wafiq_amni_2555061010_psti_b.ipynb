# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 10
x
# Out:
# 10

# %%
#tampilkan tipe data dari x
# if we'd like more specificity (e.g., int16, uint8), we need NumPy or another numeric library
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu niali skalar
y = 10
y
# Out:
# 10

# %%
#tampilkan tipe data dari y
# if we'd like more specificity (e.g., int16, uint8), we need NumPy or another numeric library
type(y)
# Out:
# int

# %%
#jumlah x + y
py_sum = x + y
py_sum
# Out:
# 20

# %%
#buat varian bernama x_float dan simpan suatu nilai desimal
x_float = 10.0
x_float
# Out:
# 10.0

# %%
#jumlahkan x_float dengan y
x_float = 10.0
float_sum = x_float + y
float_sum
# Out:
# 20.0

# %%
#tampilkan tipe data x_float
type(py_sum)
# Out:
# int

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(10, dtype=tf.int16)
#tampilkan tipe data dari x
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=10>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(10, dtype=tf.int16)
#tampilkan tipe data dari y
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=10>

# %%
#jumlahkan x+y
tf_sum = tf.add(x_tf, y_tf)
(tf_sum)
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=20>

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable(10.0, dtype=tf.float16)
#tampilkan tipe data dari x_float
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=10.0>

# %%
#jumlahkan x_float dengan y
tf_float_sum = tf.add(tf.cast(y_tf, dtype = tf.float16), x_float_tf)
print(tf_float_sum)
# Out:
# tf.Tensor(20.0, shape=(), dtype=float16)

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(10)
x_pt
# Out:
# tensor(10)

# %%
#tampilkan tipe data dari x
x_pt.dtype
# Out:
# torch.int64

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(10)
y_pt
# Out:
# tensor(10)

# %%
#tampilkan tipe data dari y
y_pt.dtype
# Out:
# torch.int64

# %%
#jumlahkan x+y
x_pt + y_pt
# Out:
# tensor(20)

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(10.0)
#tampilkan tipe data dari x_float
x_float_pt
# Out:
# tensor(10.)

# %%
#jumlahkan x_float dengan y
x_float_pt + y_pt
# Out:
# tensor(20.)

# %%
#tampilkan tipe data dari y_float
x_float_pt.dtype
# Out:
# torch.float32
