# %% [markdown]
# selesaikan soal berikut
#
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
v = np.array([[25],[2], [-3] ,[-23]])
v
v_t = v.T
v_t
# Out:
# array([[ 25,   2,  -3, -23]])

# %%
import torch

# %%
v_pt = torch.tensor([[25],[2], [-3] ,[-23]])
v_pt
v_pt_t = v_pt.T
v_pt_t
# Out:
# tensor([[ 25,   2,  -3, -23]])

# %%
import tensorflow as tf

# %%
v_tf = tf.Variable([[25],[2], [-3] ,[-23]])
v_tf
v_tf_t = tf.transpose(v_tf)
v_tf_t
# Out:
# <tf.Tensor: shape=(1, 4), dtype=int32, numpy=array([[ 25,   2,  -3, -23]], dtype=int32)>
