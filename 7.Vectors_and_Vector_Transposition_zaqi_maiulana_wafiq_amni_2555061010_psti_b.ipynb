# %%
import numpy as np

# %%
#buat vector x dengan ukuran 3x1
x = np.array([10, 10, 10])
x
# Out:
# array([10, 10, 10])

# %%
#hitung panjang vector x
len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
#tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
#akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(10)

# %%
#tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %%
#2 lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([10, 10, 10])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[10, 10, 10]])
y
y_t = y.T
y_t
# Out:
# array([[10],
#        [10],
#        [10]])

# %%
#tampilkan ukuran dari vector y_t
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow

# %%
import torch
import tensorflow as tf

# %%
#buat vector x dengan ukuran 3x1
x_pt = torch.tensor([10, 10, 10])
x_pt
# Out:
# tensor([10, 10, 10])

# %%
#hitung panjang vector x
len(x_pt)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x_pt.shape
# Out:
# torch.Size([3])

# %%
#tampilkan tipe data dari vector x
type(x_pt)
# Out:
# torch.Tensor

# %%
#akses elemen pertama dari vector x
x_pt[0]
# Out:
# tensor(10)

# %%
#akses elemen pertama dari vector x
x_pt[0]
# Out:
# tensor(10)

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_t
x_pt_t = x_pt
x_pt_t
# Out:
# tensor([10, 10, 10])

# %%
#tampilkan ukuran dari vector x_t
x_pt_t.shape
# Out:
# torch.Size([3])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y_pt = np.array([[10, 10, 10]])
y_pt
y_pt_t = y_pt.T
y_pt_t
# Out:
# array([[10],
#        [10],
#        [10]])

# %%
#tampilkan ukuran dari vector y_t
y_pt_t.shape
# Out:
# (3, 1)

# %% [markdown]
# TENSORFLOW

# %%
#buat vector x dengan ukuran 3x1
x_tf = tf.Variable([10, 10, 10])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 10, 10], dtype=int32)>

# %%
#tampilkan ukuran vector x
x_tf.shape
# Out:
# TensorShape([3])

# %%
#tampilkan tipe data dari vector x
x_tf.dtype
# Out:
# tf.int32

# %%
#akses elemen pertama dari vector x
x_tf[0]
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_t
x_tf_t = x_tf
x_tf_t
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 10, 10], dtype=int32)>

# %%
#tampilkan ukuran dari vector x_t
x_tf_t.shape
# Out:
# TensorShape([3])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y_tf = np.array([[10, 10, 10]])
y_tf
y_tf_t = y_tf.T
y_tf_t
# Out:
# array([[10],
#        [10],
#        [10]])

# %%
#tampilkan ukuran dari vector y_t
y_tf_t.shape
# Out:
# (3, 1)
