# %%
import numpy as np

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[10, 10], [10, 10], [10, 10]])
X
# Out:
# array([[10, 10],
#        [10, 10],
#        [10, 10]])

# %%
#tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([10, 10, 10])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([10, 10])

# %% [markdown]
# 2.ulangi soal nomor 1 menggunakan pytorch

# %%
import torch

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
X_pt = torch.tensor([[10, 10], [10, 10], [10, 10]])
X_pt
# Out:
# tensor([[10, 10],
#         [10, 10],
#         [10, 10]])

# %%
#tampilkan ukuran dari matrix X
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X_pt[:,0]
# Out:
# tensor([10, 10, 10])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X_pt[1,:]
# Out:
# tensor([10, 10])

# %% [markdown]
# ulangi soal nomor 1 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
X_tf = tf.Variable([[10, 10], [10, 10], [10, 10]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[10, 10],
#        [10, 10],
#        [10, 10]], dtype=int32)>

# %%
#tampilkan ukuran dari matrix X
X_tf.shape
# Out:
# TensorShape([3, 2])

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([10, 10, 10], dtype=int32)>

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([10, 10], dtype=int32)>
